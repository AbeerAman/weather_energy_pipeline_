# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

os.makedirs("docs/figures", exist_ok=True)
sns.set_theme(style="whitegrid")

print("All libraries loaded successfully")
# Out:
# All libraries loaded successfully

# %%
# Run this when Member 2 announces Gold layer is ready
gold = pd.read_parquet("data/gold/gold_weather_energy.parquet")

print(f"Total records: {len(gold):,}")
print(f"Date range: {gold['date'].min()} to {gold['date'].max()}")
print(f"Price zones: {list(gold['price_zone'].unique())}")
print(f"Columns: {list(gold.columns)}")

# %%
# Key numbers for the report
corr_temp_consumption = gold['avg_temp'].corr(gold['consumption_mwh'])
corr_temp_price = gold['avg_temp'].corr(gold['spot_price_sek'])

print("=" * 50)
print("KEY NUMBERS FOR YOUR REPORT")
print("=" * 50)
print(f"Temp vs consumption: {corr_temp_consumption:.3f}")
print(f"Temp vs spot price:  {corr_temp_price:.3f}")
print("=" * 50)

# %%
# Chart 1: Temperature vs Consumption
plt.figure(figsize=(10, 6))
plt.scatter(gold['avg_temp'], gold['consumption_mwh'], alpha=0.2, s=1)
plt.xlabel("Average Temperature (°C)")
plt.ylabel("Electricity Consumption (MWh)")
plt.title("Temperature vs Energy Consumption across Sweden")
plt.savefig("docs/figures/chart1_temp_vs_consumption.png",
            dpi=150, bbox_inches='tight')
plt.show()
print("Chart 1 saved")

# %%
# Chart 2: Monthly consumption by price zone
monthly = gold.groupby(['year','month','price_zone'])['consumption_mwh'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly, x='month', y='consumption_mwh', hue='price_zone')
plt.xlabel("Month")
plt.ylabel("Average Consumption (MWh)")
plt.title("Monthly Average Energy Consumption by Price Zone")
plt.savefig("docs/figures/chart2_monthly_by_zone.png",
            dpi=150, bbox_inches='tight')
plt.show()
print("Chart 2 saved")

# %%
# Chart 3: Correlation heatmap
cols = ['avg_temp','rolling_24h_avg_temp','consumption_mwh','spot_price_sek']
plt.figure(figsize=(8, 6))
sns.heatmap(gold[cols].corr(), annot=True, fmt='.2f',
            cmap='coolwarm', center=0)
plt.title("Correlation Matrix: Weather and Energy Variables")
plt.savefig("docs/figures/chart3_heatmap.png",
            dpi=150, bbox_inches='tight')
plt.show()
print("Chart 3 saved")

# %%
# Chart 4: Rolling temperature vs spot price
plt.figure(figsize=(10, 6))
sns.scatterplot(data=gold, x='rolling_24h_avg_temp',
                y='spot_price_sek', hue='price_zone',
                alpha=0.4, s=10)
plt.xlabel("24-hour Rolling Average Temperature (°C)")
plt.ylabel("Spot Price (SEK/MWh)")
plt.title("Rolling Temperature vs Electricity Spot Price by Zone")
plt.savefig("docs/figures/chart4_rolling_vs_price.png",
            dpi=150, bbox_inches='tight')
plt.show()
print("Chart 4 saved")
```

After pasting all cells press **Ctrl + S** to save the notebook.

---

## Then Push to GitHub

Go back to Command Prompt and run:
```
git add .
git commit -m "add analysis notebook 04_analysis"
git push origin member5-analysis
